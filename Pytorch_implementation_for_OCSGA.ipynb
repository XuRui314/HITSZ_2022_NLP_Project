# %% [markdown]
# <a href="https://colab.research.google.com/github/XuRui314/HITSZ_2022_NLP_Project/blob/main/Pytorch_implementation_for_OCSGA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# This is the method how to download the model from github to colab:
# cd drive/MyDrive
# !git clone https://github.com/softhuafei/Pytorch-implementation-for-OCSGA.git
# Out:
# Cloning into 'Pytorch-implementation-for-OCSGA'...
# remote: Enumerating objects: 52, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (45/45), done.
# remote: Total 52 (delta 2), reused 41 (delta 0), pack-reused 0
# Unpacking objects: 100% (52/52), done.

# %%
# !nvidia-smi
# Out:
# Fri May 20 13:33:51 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8    26W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import os
os.chdir("/content/drive/MyDrive/Pytorch-implementation-for-OCSGA")
# !ls
# Out:
# data	 model	    object_detector  sample.train.config
# main.py  model.png  README.md	     utils

# %%
# !pip install transformers
# Out:
# ...
#      |████████████████████████████████| 4.2 MB 5.2 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 36.1 MB/s
# ...
#      |████████████████████████████████| 596 kB 34.8 MB/s
# ...
#      |████████████████████████████████| 84 kB 3.2 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
# 这个也是必须要做的，因为不check cuda的话可能会检测不到
print(torch.cuda.device_count())
print(torch.cuda.is_available())
# Out:
# 1
# True

# %%
# !python main.py --config sample.train.config
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# Entity type:  all p =  0.7080028839221341  r =  0.6351875808538163  f =  0.6696215479031707
# Dev: time: 1.95s, speed: 516.59st/s; acc: 0.9316, p: 0.7080, r: 0.6352, f: 0.6696
# Entity type:  PER p =  0.7829255596043727  r =  0.8281938325991189  f =  0.8049237356168049
# Entity type:  LOC p =  0.7194202898550724  r =  0.7312905126694166  f =  0.7253068381063705
# Entity type:  ORG p =  0.5254237288135594  r =  0.4064362336114422  f =  0.45833333333333337
# Entity type:  OTHER p =  0.3835125448028674  r =  0.14738292011019283  f =  0.21293532338308457
# Entity type:  all p =  0.6980760822037604  r =  0.6287908625443088  f =  0.6616245337753833
# Test: time: 6.23s, speed: 527.13st/s; acc: 0.9293, p: 0.6981, r: 0.6288, f: 0.6616
# Epoch: 8/200
#  Learning rate is set as: 0.0035714285714285718
# Shuffle: first input word list: [7083, 7906, 5, 4400, 11990, 6479, 169, 5523, 15517, 267, 1372, 15518, 659, 169, 159, 2186, 14, 15519, 149, 1258, 844, 15, 15520]
# ...
